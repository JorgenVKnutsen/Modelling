# %%
from sympy import *
from sympy.physics.mechanics import * 
import numpy as np
from scipy.integrate import odeint, ode, solve_ivp


init_vprinting()

# %%
g, m1, m2, m3, ell1, ell2, ell3, t = symbols('g m1 m2 m3 ell1 ell2 ell3 t')
theta1, theta2, theta3 = dynamicsymbols('theta1 theta2 theta3')

xm1 = ell1*sin(theta1)
ym1 = - ell1*cos(theta1)

xm2 = ell1*sin(theta1) + ell2*sin(theta2)
ym2 = - ell1*cos(theta1) - ell2*cos(theta2)

xm3 = ell1*sin(theta1) + ell2*sin(theta2) + ell3*sin(theta3)
ym3 = - ell1*cos(theta1) - ell2*cos(theta2) - ell3*cos(theta3)



# time derivatives
xm1_dot = diff(xm1, t)
ym1_dot = diff(ym1, t)

xm2_dot = diff(xm2, t)
ym2_dot = diff(ym2, t)

xm3_dot = diff(xm3, t)
ym3_dot = diff(ym3, t)

theta1_dot = diff(theta1, t)
theta1_ddot = diff(theta1_dot, t)

theta2_dot = diff(theta2, t)
theta2_ddot = diff(theta2_dot, t)

theta3_dot = diff(theta3, t)
theta3_ddot = diff(theta3_dot, t)


#Defining kinetic energy
T = 1/2 * m1 * (xm1_dot**2 + ym1_dot**2) + 1/2 * m2 * (xm2_dot**2 + ym2_dot **2) + 1/2 * m3 * (xm3_dot**2 + ym3_dot **2)

#Defining potential energy   m*g*h = m * g * y
V = m1 * g * ym1 + m2 * g * ym2 + m3 * g * ym3

#Lagrangian
L = T - V 

eqn1 = diff(diff(L, theta1_dot), t) - diff(L, theta1)
eqn2 = diff(diff(L, theta2_dot), t) - diff(L, theta2)
eqn3 = diff(diff(L, theta3_dot), t) - diff(L, theta3)

sln1 = simplify(solve(eqn1, theta1_ddot)[0])
sln2 = simplify(solve(eqn2, theta2_ddot)[0])
sln3 = simplify(solve(eqn3, theta3_ddot)[0])


x = Matrix([theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot])
x_dot = diff(x, t)


Eq(x_dot, Matrix([theta1_dot, sln1, theta2_dot, sln2, theta3_dot, sln3]))
# Out:
#        ⎡
#        ⎢
#        ⎢ ⎛                       2
#        ⎢-⎝ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₂⋅m₂⋅cos(θ₁ - θ₂)⋅θ₂̈ + ell₂⋅m₃⋅sin(θ
#        ⎢──────────────────────────────────────────────────────────────────────
# ⎡θ₁̇⎤   ⎢
# ⎢  ⎥   ⎢
# ⎢θ₁̈⎥   ⎢
# ⎢  ⎥   ⎢
# ⎢θ₂̇⎥   ⎢                                2
# ⎢  ⎥ = ⎢         ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₁⋅m₂⋅cos(θ₁ - θ₂)⋅θ₁̈ + ell₁⋅m
# ⎢θ₂̈⎥   ⎢         ────────────────────────────────────────────────────────────
# ⎢  ⎥   ⎢
# ⎢θ₃̇⎥   ⎢
# ⎢  ⎥   ⎢
# ⎣θ₃̈⎦   ⎢
#        ⎢
#        ⎢                                                   ell₁⋅sin(θ₁ - θ₃)⋅θ
#        ⎢                                                   ───────────────────
#        ⎣
#
#                                θ₁̇
#
#         2                                                    2
# ₁ - θ₂)⋅θ₂̇  + ell₂⋅m₃⋅cos(θ₁ - θ₂)⋅θ₂̈ + ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  + ell₃⋅m₃⋅
# ──────────────────────────────────────────────────────────────────────────────
#                         ell₁⋅(m₁ + m₂ + m₃)
#
#                                 θ₂̇
#
#                 2                                                    2
# ₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₁⋅m₃⋅cos(θ₁ - θ₂)⋅θ₁̈ - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - e
# ──────────────────────────────────────────────────────────────────────────────
#                          ell₂⋅(m₂ + m₃)
#
#                                θ₃̇
#
#  2                                              2
# ₁̇  - ell₁⋅cos(θ₁ - θ₃)⋅θ₁̈ + ell₂⋅sin(θ₂ - θ₃)⋅θ₂̇  - ell₂⋅cos(θ₂ - θ₃)⋅θ₂̈ -
# ──────────────────────────────────────────────────────────────────────────────
#                                ell₃
#
#                                                           ⎤
#                                                          ⎥
#                                                        ⎞ ⎥
# cos(θ₁ - θ₃)⋅θ₃̈ + g⋅m₁⋅sin(θ₁) + g⋅m₂⋅sin(θ₁) + g⋅m₃⋅sin(θ₁)⎠ ⎥
# ─────────────────────────────────────────────────────────⎥
#                                                           ⎥
#                                                          ⎥
#                                                            ⎥
#                                                          ⎥
#                                                           ⎥
# ll₃⋅m₃⋅cos(θ₂ - θ₃)⋅θ₃̈ - g⋅m₂⋅sin(θ₂) - g⋅m₃⋅sin(θ₂)          ⎥
# ────────────────────────────────────────────────          ⎥
#                                                          ⎥
#                                                           ⎥
#                                                           ⎥
#                                                           ⎥
#                                                          ⎥
#  g⋅sin(θ₃)                                                   ⎥
# ──────                                                   ⎥
#                                                          ⎦

# %%
sln1_corrected = -(ell2*m2*sin(theta1 - theta2)*theta2_dot**2 + ell2*m3*sin(theta1-theta2)*theta2_dot**2 + ell3*m3*sin(theta1-theta3)*theta3_dot**2+ g*(m1+m2+m3)*sin(theta1))/(ell1*(m1+m2+m3))
sln2_corrected = (ell1*m2*sin(theta1-theta2)*theta1_dot**2 + ell1*m3*sin(theta1-theta2)*theta1_dot**2 - ell3*m3*sin(theta2-theta3)*theta3_dot**2 - g*(m2+m3)*sin(theta2))/(ell2*(m2+m3))
sln3_corrected = (ell1*sin(theta1-theta3)*theta1_dot**2 + ell2*sin(theta2-theta3)*theta2_dot**2-g*sin(theta3))/ell3
sln1_corrected
# Out:
#                          2                          2
# - ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₃⋅m₃⋅sin(θ₁ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#                                             ell₁⋅(m₁ + m₂ + m₃)
#
#  2
# ⋅θ₃̇  - g⋅(m₁ + m₂ + m₃)⋅sin(θ₁)
# ─────────────────────────────

# %%
correction_matrix = Matrix([[1,0,0,0,0,0],
                            [0,1,0,(m2+m3)*ell2*cos(theta1-theta2)/(ell1*(m1+m2+m3)), 0, ell3*m3*cos(theta1 - theta2)/(ell1*(m1+m2+m3))],
                            [0,0,1,0,0,0],
                            [0, ell1*(m2+m3)*cos(theta1-theta2)/(ell2*(m2+m3)), 0, 1, 0, ell3*m3*cos(theta2-theta3)/(ell2*(m2+m3))],
                            [0,0,0,0,1,0],
                            [0, ell1*cos(theta1-theta3)/ell3, 0, ell2*cos(theta2-theta3)/ell3, 0, 1]])
correction_matrix
# Out:
# ⎡1          0          0               0               0           0
# ⎢
# ⎢                         ell₂⋅(m₂ + m₃)⋅cos(θ₁ - θ₂)     ell₃⋅m₃⋅cos(θ₁ - θ₂)
# ⎢0          1          0  ───────────────────────────  0  ────────────────────
# ⎢                             ell₁⋅(m₁ + m₂ + m₃)         ell₁⋅(m₁ + m₂ + m₃)
# ⎢
# ⎢0          0          1               0               0           0
# ⎢
# ⎢   ell₁⋅cos(θ₁ - θ₂)                                     ell₃⋅m₃⋅cos(θ₂ - θ₃)
# ⎢0  ─────────────────  0               1               0  ────────────────────
# ⎢          ell₂                                              ell₂⋅(m₂ + m₃)
# ⎢
# ⎢0          0          0               0               1           0
# ⎢
# ⎢   ell₁⋅cos(θ₁ - θ₃)          ell₂⋅cos(θ₂ - θ₃)
# ⎢0  ─────────────────  0       ─────────────────       0           1
# ⎣          ell₃                       ell₃
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
correction_matrix_inv = correction_matrix.inv()
correction_matrix_inv
# Out:
# ⎡1
# ⎢
# ⎢
# ⎢
# ⎢0                                            ────────────────────────────────
# ⎢                                                              2
# ⎢                                             m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁
# ⎢
# ⎢0
# ⎢
# ⎢
# ⎢
# ⎢0  ──────────────────────────────────────────────────────────────────────────
# ⎢                              2                                2    2
# ⎢   ell₂⋅m₁⋅m₂ - ell₂⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₂⋅m₁⋅m₃ - ell₂⋅m₂ ⋅cos (θ₁ - θ₂
# ⎢
# ⎢0
# ⎢
# ⎢
# ⎢
# ⎢0  ──────────────────────────────────────────────────────────────────────────
# ⎢                              2                                2    2
# ⎣   ell₃⋅m₁⋅m₂ - ell₃⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₃⋅m₁⋅m₃ - ell₃⋅m₂ ⋅cos (θ₁ - θ₂
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         2    2              2            2
# ⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos
#
#
#
#
#                                           -ell₁⋅m₁⋅m₂⋅cos(θ₁ - θ₂) - ell₁⋅m₁⋅m
# ──────────────────────────────────────────────────────────────────────────────
#            2                 2                                         2
# ) + ell₂⋅m₂  + ell₂⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos (θ₁ -
#
#
#
#
#     ell₁⋅m₁⋅m₂⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₁⋅m₂⋅cos(θ₁ - θ₃) + ell₁⋅m₁⋅m
# ──────────────────────────────────────────────────────────────────────────────
#            2                 2                                         2
# ) + ell₃⋅m₂  + ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₃⋅m₂⋅m₃⋅cos (θ₁ -
#
#
#
#                                                     2                      2
#                                    m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ + m₂  -
# ──────────────────────────────────────────────────────────────────────────────
# 2
#  (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)
#
#
#
#                                                                2
# ₃⋅cos(θ₁ - θ₂) + ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₂ ⋅cos(θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#
# θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₂⋅m₃⋅cos(θ₁ -
#
#
#
#                                                                2
# ₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₃) + ell₁⋅m₂ ⋅cos(θ₁ - θ₂)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# θ₂) + ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₂⋅m₃⋅cos(θ₁ -
#
#       0
#
#           2                        2    2              2
#  m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₂ - θ₃) + m₃
# ──────────────────────────────────────────────────────────────────────────────
#                          2                        2    2
# ⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃)
#
#       0
#
#                                                                             2
# - 2⋅ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                  2                                  2    2
# θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅m₃ + ell₂⋅m₃ ⋅cos (θ₁
#
#       0
#
#                       2
# cos(θ₂ - θ₃) - ell₁⋅m₂ ⋅cos(θ₁ - θ₃) + 2⋅ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#                                  2                                  2    2
# θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₃⋅m₂⋅m₃ + ell₃⋅m₃ ⋅cos (θ₁
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2    2              2                                            2
#  - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁
#
#
#
#                       2
# cos(θ₁ - θ₂) + ell₁⋅m₃ ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#                             2    2                   2
# - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos (θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ
#
#
#
#                                      2                                    2
# - 2⋅ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₃) + ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅co
# ──────────────────────────────────────────────────────────────────────────────
#                             2    2                   2
# - θ₂)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos (θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ
#
#
#
#
#
# ─────────────────────────────────────────────
#                         2    2              2
#  - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                          2                                    2    2
# ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₃ ⋅cos (θ₂ - θ₃)
#
#
#
#
# s(θ₁ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#                          2                                    2    2
# ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₃ ⋅cos (θ₂ - θ₃)
#
#             0
#
#
#
#             0  ───────────────────────────────────────────────────────────────
#                                           2                                2
#                ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅m₁⋅m₃ - ell₁⋅m₂ ⋅c
#
#             1
#
#
#
# ──────────  0                                            ─────────────────────
#          2                                                                2
# + ell₂⋅m₃                                                m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂
#
#             0
#
#
#
# ──────────  0  ───────────────────────────────────────────────────────────────
#          2                                2                                2
# + ell₃⋅m₃      ell₃⋅m₁⋅m₂ - ell₃⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₃⋅m₁⋅m₃ - ell₃⋅m₂ ⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                   2                 2
# os (θ₁ - θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₁⋅m₂⋅m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                    2    2              2            2
#  - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) -
#
#
#
#
#                                                      -ell₂⋅m₁⋅m₂⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#   2                   2                 2
# os (θ₁ - θ₂) + ell₃⋅m₂  + ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₃⋅m₂⋅m₃
#
#
#
#                              2
#                     - ell₂⋅m₂ ⋅cos(θ₁ - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ -
# ──────────────────────────────────────────────────────────────────────────────
#     2
# ⋅cos (θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₂⋅m
#
#
#
#                                                                2
#                                              m₁⋅m₂ + m₁⋅m₃ + m₂  - m₂⋅m₃⋅cos(θ
# ──────────────────────────────────────────────────────────────────────────────
#            2
# 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅c
#
#
#
#                                    2                                    2
# - ell₂⋅m₁⋅m₃⋅cos(θ₂ - θ₃) + ell₂⋅m₂ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₂ ⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#     2
# ⋅cos (θ₁ - θ₂) + ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₂⋅m
#
#                  0
#
#                                           2
#  θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m
# ──────────────────────────────────────────────────────────────────────────────
#                                             2
# ₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₁⋅m₂⋅m₃ + ell₁⋅m
#
#                  0
#
#                                    2                               2
# ₁ - θ₂)⋅cos(θ₁ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + m₃
# ──────────────────────────────────────────────────────────────────────────────
#                                     2                        2    2
# os(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅c
#
#                  0
#
#
# θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#                                             2
# ₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₃⋅m₂⋅m₃ + ell₃⋅m
#
#
#
#  2
# ₃ ⋅cos(θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#  2    2                                2    2                   2
# ₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell₁⋅m₃ ⋅cos(θ₁ - θ₂)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                 2    2              2
# os(θ₂ - θ₃) - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) -
#
#
#
#          2                                    2
# + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₃ ⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#  2    2                                2    2                   2
# ₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos (θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                     2                                    2
# ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₃ ⋅cos
#
#
#
#
#
# ────────────────────────────────────────────────────────
#    2                               2    2              2
#  m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                     2                                    2
# ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₃ ⋅cos
#
#                        0
#
#
#
# ─────────────────────  0  ────────────────────────────────────────────────────
# 2                   2                                2
#  (θ₂ - θ₃) + ell₁⋅m₃      ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅m₁⋅m₃ -
#
#                        0
#
#
#
#                        0  ────────────────────────────────────────────────────
#                                                      2
#                           ell₂⋅m₁⋅m₂ - ell₂⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₂⋅m₁⋅m₃ -
#
#                        1
#
#
#
# ─────────────────────  0                                            ──────────
# 2                   2
#  (θ₂ - θ₃) + ell₃⋅m₃                                                m₁⋅m₂ - m₁
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         2    2                   2                 2
#  ell₁⋅m₂ ⋅cos (θ₁ - θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         2    2                   2                 2
#  ell₂⋅m₂ ⋅cos (θ₁ - θ₂) + ell₂⋅m₂  + ell₂⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        2                      2    2              2            2
# ⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(
#
#
#
#
#                                              ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ -
# ──────────────────────────────────────────────────────────────────────────────
#                2
# ⋅ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)
#
#
#
#
#                                             -ell₃⋅m₁⋅m₃⋅cos(θ₂ - θ₃) + ell₃⋅m₂
# ──────────────────────────────────────────────────────────────────────────────
#                2
# ⋅ell₂⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)
#
#
#
#                                                                            2
#                                                          m₁⋅m₂ + m₁⋅m₃ - m₂ ⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                       2
# θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃
#
#                             0
#
#                                        2                                    2
# θ₃) - ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
# - ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₁⋅m₂⋅
#
#                             0
#
#        2                                             2    2
# ⋅m₃⋅cos (θ₁ - θ₂) - ell₃⋅m₂⋅m₃⋅cos(θ₂ - θ₃) + ell₃⋅m₃ ⋅cos (θ₁ - θ₂) - ell₃⋅m₃
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
# - ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅
#
#                             0
#
#   2              2              2                        2    2              2
# os (θ₁ - θ₂) + m₂  - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₁ - θ₂) + m₃
# ──────────────────────────────────────────────────────────────────────────────
#                                                2                        2    2
# ) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos
#
#
#
#
# cos(θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#             2    2                                2    2                   2
# m₃ + ell₁⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell₁⋅m₃ ⋅c
#
#
#
# 2
#  ⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#             2    2                                2    2                   2
# m₃ + ell₂⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos (θ₁ - θ₂) + ell₂⋅m₃ ⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                            2    2              2
# (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
# os(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - e
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
# os(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - e
#
#
#
#
#
# ───────────────────────────────────────────────────────────────────
#               2                               2    2              2
# (θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃
#
#                                 ⎤
#                                 ⎥
#                                 ⎥
#                                 ⎥
# ────────────────────────────────⎥
#       2    2                   2⎥
# ll₁⋅m₃ ⋅cos (θ₂ - θ₃) + ell₁⋅m₃ ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
# ────────────────────────────────⎥
#       2    2                   2⎥
# ll₂⋅m₃ ⋅cos (θ₂ - θ₃) + ell₂⋅m₃ ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎦

# %%
A = Matrix([theta1_dot, sln1_corrected, theta2_dot, sln2_corrected, theta3_dot, sln3_corrected])
A

ODE_equations = correction_matrix_inv * A
ODE_equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢     ⎛                           2                                2    2
# ⎢ell₃⋅⎝ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅m₁⋅m₃ - ell₁⋅m₂ ⋅cos (θ₁ -
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢     ⎛                           2                                2    2
# ⎢ell₃⋅⎝ell₂⋅m₁⋅m₂ - ell₂⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₂⋅m₁⋅m₃ - ell₂⋅m₂ ⋅cos (θ₁ -
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢     ⎛                 2                      2    2              2
# ⎣ell₃⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅c
#
#
#
#                                                                        ⎛
#                                                                       ⎝ell₁⋅si
# ──────────────────────────────────────────────────────────────────────────────
#               2                 2                                         2
#  θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₁⋅m₂⋅m₃⋅cos (θ₁
#
#
#
#                                                                       ⎛
#                                                                      ⎝ell₁⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#               2                 2                                         2
#  θ₂) + ell₂⋅m₂  + ell₂⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos (θ₁
#
#
#
#                                         ⎛                    2
#                                        ⎝ell₁⋅sin(θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ -
# ──────────────────────────────────────────────────────────────────────────────
#   2                                    2
# os (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁
#
#
#
#               2                       2            ⎞ ⎛
# n(θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅θ₂̇  - g⋅sin(θ₃)⎠⋅⎝ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#
#  - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₂⋅m₃⋅cos(θ₁
#
#
#
#              2                       2            ⎞ ⎛
# (θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅θ₂̇  - g⋅sin(θ₃)⎠⋅⎝-ell₃⋅m₁⋅m₃⋅cos(θ₂ - θ₃)
# ──────────────────────────────────────────────────────────────────────────────
#
#  - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₂⋅m₃⋅cos(θ₁
#
#
#
#        2            ⎞ ⎛                  2    2              2              2
#  θ₃)⋅θ₂̇  - g⋅sin(θ₃)⎠⋅⎝m₁⋅m₂ + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  - 2⋅m₂⋅m₃⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2
# - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2
#
#
#
#                                                 2
# ⋅cos(θ₂ - θ₃) - ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) -
# ──────────────────────────────────────────────────────────────────────────────
#                                     2                                  2    2
#  - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₁⋅m₂⋅m₃ + ell₁⋅m₃ ⋅cos (
#
#
#
#                 2                                             2    2
#  + ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂) - ell₃⋅m₂⋅m₃⋅cos(θ₂ - θ₃) + ell₃⋅m₃ ⋅cos (θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#                                     2                                  2    2
#  - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅m₃ + ell₂⋅m₃ ⋅cos (
#
#
#
#                        2    2              2⎞
# (θ₁ - θ₂) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#            2    2                           2    2              2
# ⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)
#
#
#
#        2             ⎞
#  ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                2    2                   2
# θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁
#
#
#
#          2             ⎞
#  - ell₃⋅m₃ ⋅cos(θ₂ - θ₃)⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                2    2                   2
# θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos (θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                2                               2    2
# ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                             2                                    2    2
# - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₃ ⋅cos (θ₂ - θ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                             2                                    2    2
# - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₃ ⋅cos (θ₂ - θ
#
#
#
#
#
# ─────── + ────────────────────────────────────────────────────────────────────
#      2⎞                  ⎛                           2
#  + m₃ ⎠   ell₂⋅(m₂ + m₃)⋅⎝ell₃⋅m₁⋅m₂ - ell₃⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₃⋅m₁⋅m₃ -
#
#
#
#
#
# ────────────── + ─────────────────────────────────────────────────────────────
#             2⎞                  ⎛                           2
# ₃) + ell₁⋅m₃ ⎠   ell₂⋅(m₂ + m₃)⋅⎝ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅
#
#
#
#
#
# ────────────── + ─────────────────────────────────────────────────────────────
#             2⎞                  ⎛                 2                      2
# ₃) + ell₂⋅m₃ ⎠   ell₂⋅(m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos
#
#
#
#      ⎛                       2                          2
#    ⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ
# ──────────────────────────────────────────────────────────────────────────────
#         2    2                   2                 2
#  ell₃⋅m₂ ⋅cos (θ₁ - θ₂) + ell₃⋅m₂  + ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2
#
#
#
#                                                          ⎛
#                                                        ⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ
# ──────────────────────────────────────────────────────────────────────────────
#                2    2                   2                 2
# m₁⋅m₃ - ell₁⋅m₂ ⋅cos (θ₁ - θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ -
#
#
#
#                                        ⎛                       2
#                                      ⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁̇  + ell₁⋅m₃⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
# 2              2            2                                    2
#  (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) +
#
#
#
#      2                      ⎞ ⎛
# ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(θ₂)⎠⋅⎝-ell₂⋅m₁⋅m₂⋅cos(θ₂ - θ₃) - ell₂⋅m₁⋅m₃⋅cos(θ₂ -
# ──────────────────────────────────────────────────────────────────────────────
#                2
# ⋅ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)
#
#                                                                       θ₁̇
#
#    2                          2                          2
# ₁̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#                       2
# θ₃) - 2⋅ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂
#
#                                                                       θ₂̇
#
#             2                          2                      ⎞ ⎛
# θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(θ₂)⎠⋅⎝m₁⋅m₂ + m₁⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
# m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)
#
#                                                                       θ₃̇
#
#              2                                    2
#  θ₃) + ell₂⋅m₂ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₂ ⋅cos(θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
# - ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₃⋅m₂⋅
#
#
#
#   ⎞ ⎛         2
# θ₂)⎠⋅⎝- ell₂⋅m₂ ⋅cos(θ₁ - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2
#  - θ₃) - ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅e
#
#
#
#      2                                                 2
# ₃ + m₂  - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁
# ──────────────────────────────────────────────────────────────────────────────
#             2                        2    2                           2    2
#  - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ
#
#
#
#                                                                  2
# m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos(θ₂ - θ₃) + ell₂⋅m₃ ⋅cos(θ₁ - θ
# ──────────────────────────────────────────────────────────────────────────────
#             2    2                                2    2                   2
# m₃ + ell₃⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos (θ₁ - θ₂) + ell₃⋅m₃ ⋅c
#
#
#
#                            2                                    2
# m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos(θ₁ - θ₂
# ──────────────────────────────────────────────────────────────────────────────
#                    2    2                                2    2
# ll₁⋅m₂⋅m₃ + ell₁⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell
#
#
#
#          2⎞
# - θ₃) + m₃ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#             2                                            2
# ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁
#
#
#
#                         2             ⎞
# ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₃ ⋅cos(θ₂ - θ₃)⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
# os(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - e
#
#
#
# ⎞
# )⎠
# ──────────────────────────────────────────────────────────────────────────────
#     2                                                 2
# ₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ -
#
#
#
#
#
# ───────────────────────────────── + ──────────────────────────────────────────
#            2    2              2⎞                       ⎛
#  - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠   ell₁⋅(m₁ + m₂ + m₃)⋅⎝ell₂⋅m₁⋅m₂ - ell₂⋅m₁⋅
#
#
#
#                                                                      ⎛
#                                                                    ⎝- ell₂⋅m₂⋅
# ───────────────────────────────── + ──────────────────────────────────────────
#       2    2                   2⎞                       ⎛
# ll₃⋅m₃ ⋅cos (θ₂ - θ₃) + ell₃⋅m₃ ⎠   ell₁⋅(m₁ + m₂ + m₃)⋅⎝ell₃⋅m₁⋅m₂ - ell₃⋅m₁⋅
#
#
#
#
#
# ──────────────────────────────────────── + ───────────────────────────────────
#              2    2                   2⎞                       ⎛
# θ₃) - ell₁⋅m₃ ⋅cos (θ₂ - θ₃) + ell₁⋅m₃ ⎠   ell₁⋅(m₁ + m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅
#
#
#
#                              ⎛                         2
#                             ⎝- ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₂⋅m₃⋅sin(θ₁ - θ₂
# ──────────────────────────────────────────────────────────────────────────────
#       2                                2    2                   2
# m₃⋅cos (θ₂ - θ₃) + ell₂⋅m₁⋅m₃ - ell₂⋅m₂ ⋅cos (θ₁ - θ₂) + ell₂⋅m₂  + ell₂⋅m₂⋅m₃
#
#
#
#                  2                          2                          2
# sin(θ₁ - θ₂)⋅θ₂̇  - ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  - g⋅
# ──────────────────────────────────────────────────────────────────────────────
#       2                                2    2                   2
# m₃⋅cos (θ₂ - θ₃) + ell₃⋅m₁⋅m₃ - ell₃⋅m₂ ⋅cos (θ₁ - θ₂) + ell₃⋅m₂  + ell₃⋅m₂⋅m₃
#
#
#
#                                                                  ⎛
#                                                                 ⎝- ell₂⋅m₂⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#    2                      2    2              2            2
# cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ -
#
#
#
#     2                          2                           ⎞ ⎛
# )⋅θ₂̇  - ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  - g⋅(m₁ + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝-ell₁⋅m₁⋅m₂⋅co
# ──────────────────────────────────────────────────────────────────────────────
#     2                                         2
# ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₂⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ -
#
#
#
#                      ⎞ ⎛
# (m₁ + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝ell₁⋅m₁⋅m₂⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₁⋅m₂⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#     2                                         2
# ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₃⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₃⋅m₂⋅m₃⋅cos(θ₁ -
#
#
#
#              2                          2                          2
# (θ₁ - θ₂)⋅θ₂̇  - ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  - g⋅(m₁
# ──────────────────────────────────────────────────────────────────────────────
#                   2
#  θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) -
#
#
#
#
# s(θ₁ - θ₂) - ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₂) + ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) -
# ──────────────────────────────────────────────────────────────────────────────
#
#  θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m
#
#
#
#
# (θ₁ - θ₃) + ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₁⋅m₃⋅cos(θ₁ - θ₃) + e
# ──────────────────────────────────────────────────────────────────────────────
#
#  θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m
#
#
#
#                  ⎞ ⎛                 2                      2            2
#  + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ + m₂  - m₂⋅m₃⋅cos (θ
# ──────────────────────────────────────────────────────────────────────────────
#                                            2                        2    2
# m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁
#
#
#
#      2
# ell₁⋅m₂ ⋅cos(θ₁ - θ₂) - 2⋅ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₃)⋅co
# ──────────────────────────────────────────────────────────────────────────────
#         2                                  2    2
# ₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₂⋅m₂⋅m₃ + ell₂⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂
#
#
#
#      2                                    2
# ll₁⋅m₂ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₂ ⋅cos(θ₁ - θ₃) + 2⋅ell₁⋅m₂⋅m₃⋅cos(θ
# ──────────────────────────────────────────────────────────────────────────────
#         2                                  2    2
# ₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₃⋅m₂⋅m₃ + ell₃⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₃
#
#
#
#                     2    2              2⎞
# ₂ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                        2    2              2
# - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂
#
#
#
#                   2                       2                          ⎞
# s(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂) + ell₁⋅m₃ ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)⎠
# ──────────────────────────────────────────────────────────────────────────────
#    2    2                   2
# ⋅m₃ ⋅cos (θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₂⋅m₃
#
#
#
#                                                          2
# ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₃) + ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ
# ──────────────────────────────────────────────────────────────────────────────
#    2    2                   2
# ⋅m₃ ⋅cos (θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₃⋅m₃
#
#                                                                  ⎤
#                                                                 ⎥
#                                                                 ⎥
#                                                                 ⎥
# ────────────────────────────────────────────────────────────────⎥
#           2                               2    2              2⎞⎥
# - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠⎥
#                                                                 ⎥
#                                                                  ⎥
#                                                                 ⎥
#                                                                 ⎥
#                                                                 ⎥
# ────────────────────────────────────────────────────────────────⎥
# 2                                    2    2                   2⎞⎥
#  ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₂⋅m₃ ⋅cos (θ₂ - θ₃) + ell₂⋅m₃ ⎠⎥
#                                                                 ⎥
#                                                                  ⎥
#                                                                 ⎥
#                 2             ⎞                                 ⎥
# ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₃)⎠                                ⎥
# ────────────────────────────────────────────────────────────────⎥
# 2                                    2    2                   2⎞⎥
#  ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₃⋅m₃ ⋅cos (θ₂ - θ₃) + ell₃⋅m₃ ⎠⎦

# %%
ODE_equations[1]
# Out:
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      ⎛                           2                                2    2
# ell₃⋅⎝ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅m₁⋅m₃ - ell₁⋅m₂ ⋅cos (θ₁ -
#
#                                                                       ⎛
#                                                                      ⎝ell₁⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#              2                 2                                         2
# θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₁⋅m₂⋅m₃⋅cos (θ₁
#
#              2                       2            ⎞ ⎛
# (θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅θ₂̇  - g⋅sin(θ₃)⎠⋅⎝ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₂⋅m₃⋅cos(θ₁
#
#                                                2
# cos(θ₂ - θ₃) - ell₃⋅m₂⋅m₃⋅cos(θ₁ - θ₂) + ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) -
# ──────────────────────────────────────────────────────────────────────────────
#                                    2                                  2    2
# - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅ell₁⋅m₂⋅m₃ + ell₁⋅m₃ ⋅cos (θ
#
#       2             ⎞
# ell₃⋅m₃ ⋅cos(θ₁ - θ₂)⎠
# ──────────────────────────────────────────────────────────────────────────────
#                               2    2                   2
# ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                            2                                    2    2
#  θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₃ ⋅cos (θ₂ - θ₃
#
#
#
# ───────────── + ──────────────────────────────────────────────────────────────
#            2⎞                  ⎛                           2
# ) + ell₁⋅m₃ ⎠   ell₂⋅(m₂ + m₃)⋅⎝ell₁⋅m₁⋅m₂ - ell₁⋅m₁⋅m₃⋅cos (θ₂ - θ₃) + ell₁⋅m
#
#                                                         ⎛
#                                                       ⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁
# ──────────────────────────────────────────────────────────────────────────────
#               2    2                   2                 2
# ₁⋅m₃ - ell₁⋅m₂ ⋅cos (θ₁ - θ₂) + ell₁⋅m₂  + ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ
#
#   2                          2                          2
# ̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(θ
# ──────────────────────────────────────────────────────────────────────────────
#                      2
# ₃) - 2⋅ell₁⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂
#
#  ⎞ ⎛         2
# ₂)⎠⋅⎝- ell₂⋅m₂ ⋅cos(θ₁ - θ₂) + ell₂⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅ell₂⋅m
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2
# - θ₃) - ell₁⋅m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - ell₁⋅m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅el
#
#                           2                                    2             ⎞
# ₂⋅m₃⋅cos(θ₁ - θ₂) + ell₂⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₂⋅m₃ ⋅cos(θ₁ - θ₂)
# ──────────────────────────────────────────────────────────────────────────────
#                   2    2                                2    2
# l₁⋅m₂⋅m₃ + ell₁⋅m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos (θ₁ - θ₂) + ell₁
#
#
# ⎠
# ──────────────────────────────────────────────────────────────────────────────
#    2                                                 2
# ⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - ell₁⋅m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ
#
#
#
# ─────────────────────────────────────── + ────────────────────────────────────
#             2    2                   2⎞                       ⎛
# ₃) - ell₁⋅m₃ ⋅cos (θ₂ - θ₃) + ell₁⋅m₃ ⎠   ell₁⋅(m₁ + m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅c
#
#                                                                 ⎛
#                                                                ⎝- ell₂⋅m₂⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#   2                      2    2              2            2
# os (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ -
#
#             2                          2                          2
# θ₁ - θ₂)⋅θ₂̇  - ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  - ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  - g⋅(m₁
# ──────────────────────────────────────────────────────────────────────────────
#                  2
# θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m
#
#                 ⎞ ⎛                 2                      2            2
# + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ + m₂  - m₂⋅m₃⋅cos (θ₂
# ──────────────────────────────────────────────────────────────────────────────
#                                           2                        2    2
# ₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ -
#
#                    2    2              2⎞
#  - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                       2    2              2
#  θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ -
#
#
#
# ───────────────────────────────────────────────────────────────
#          2                               2    2              2⎞
#  θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠

# %%
simplified_ODE1 = simplify(ODE_equations[1])

# %%
simplified_ODE3 = simplify(ODE_equations[3])

# %%
simplified_ODE5 = simplify(ODE_equations[5])

# %%
C = Matrix([theta1_dot, simplified_ODE1, theta2_dot, simplified_ODE3, theta3_dot, simplified_ODE5])
Eq(x_dot, C)
# Out:
#        ⎡
#        ⎢
#        ⎢
#        ⎢
#        ⎢
#        ⎢
#        ⎢
# ⎡θ₁̇⎤   ⎢
# ⎢  ⎥   ⎢
# ⎢θ₁̈⎥   ⎢
# ⎢  ⎥   ⎢
# ⎢θ₂̇⎥   ⎢
# ⎢  ⎥ = ⎢
# ⎢θ₂̈⎥   ⎢
# ⎢  ⎥   ⎢
# ⎢θ₃̇⎥   ⎢
# ⎢  ⎥   ⎢
# ⎣θ₃̈⎦   ⎢
#        ⎢
#        ⎢                         ⎛                    2
#        ⎢(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝ell₁⋅sin(θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅θ
#        ⎢
#        ⎢──────────────────────────────────────────────────────────────────────
#        ⎢
#        ⎣
#
#
#
#
#
#
#
#
#
#
#
#                                ⎛                    2                       2
#   - m₃⋅(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝ell₁⋅sin(θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅θ₂
#  ─────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# 2            ⎞ ⎛                  2    2              2              2
# ₂̇  - g⋅sin(θ₃)⎠⋅⎝m₁⋅m₂ + m₁⋅m₃ - m₂ ⋅cos (θ₁ - θ₂) + m₂  - 2⋅m₂⋅m₃⋅cos (θ₁ -
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                   ⎛                    2
#       m₃⋅(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝ell₁⋅sin(θ₁ - θ₃)⋅θ₁̇  + ell₂⋅sin(θ₂ - θ₃)⋅
#       ────────────────────────────────────────────────────────────────────────
#
#                                                                              e
#
#
#
#            ⎞ ⎛                        2                                    2
# ̇  - g⋅sin(θ₃)⎠⋅⎝m₁⋅cos(θ₂ - θ₃) - m₂⋅cos (θ₁ - θ₂) + m₂⋅cos(θ₂ - θ₃) - m₃⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                             el
#
#
#
#                                                    ⎛                       2
#                 2    2              2⎞   (m₂ + m₃)⋅⎝ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇
# θ₂) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₁ - θ₂) + m₃ ⎠ - ───────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                              e
#
#
#
#  2            ⎞
# θ₂̇  - g⋅sin(θ₃)⎠⋅(m₂⋅cos(θ₂ - θ₃) - m₂ + m₃⋅cos(θ₂ - θ₃) - m₃)⋅cos(θ₁ - θ₂) -
# ──────────────────────────────────────────────────────────────────────────────
#                              ⎛                 2                      2    2
# ll₁⋅(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ
#
#
#
#                          ⎞             ⎛                       2
#  (θ₁ - θ₂) + m₃⋅cos(θ₂ - θ₃)⎠ + (m₂ + m₃)⋅⎝ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₂⋅m₃
# ──────────────────────────────────────────────────────────────────────────────
#                              ⎛                 2                      2    2
# l₂⋅(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ₁
#
#
#
#                         2                          2
# + ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  + g⋅(m₁ + m₂ + m₃)⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#                              ⎛                 2                      2    2
# ll₃⋅(m₂ + m₃)⋅(m₁ + m₂ + m₃)⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅m₃ - m₂ ⋅cos (θ
#
#
#
#          ⎛                       2                          2
#  (m₂ + m₃)⋅⎝ell₂⋅m₂⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₂⋅m₃⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₃⋅m₃⋅si
# ──────────────────────────────────────────────────────────────────────────────
#             2            2                                    2
# ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅
#
#
#
#             2                          2                           ⎞ ⎛
# ⋅sin(θ₁ - θ₂)⋅θ₂̇  + ell₃⋅m₃⋅sin(θ₁ - θ₃)⋅θ₃̇  + g⋅(m₁ + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝m₁
# ──────────────────────────────────────────────────────────────────────────────
#             2            2                                    2
#  - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅m
#
#
#
#  ⎞ ⎛
# (θ₁)⎠⋅⎝-m₁⋅m₂⋅cos(θ₁ - θ₃) + m₁⋅m₂⋅cos(θ₁ - 2⋅θ₂ + θ₃) - m₁⋅m₃⋅cos(θ₁ - θ₃) +
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2
# ──────────────────────────────────────────────────────────────────────────────
#             2            2                                    2
# ₁ - θ₂) + m₂  + m₂⋅m₃⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - 2⋅m₂⋅m₃⋅cos (θ₁ - θ₂) + m₂⋅
#
#                                                     θ₁̇
#
#          2                           ⎞ ⎛                 2
# n(θ₁ - θ₃)⋅θ₃̇  + g⋅(m₁ + m₂ + m₃)⋅sin(θ₁)⎠⋅⎝m₁⋅m₂ - m₁⋅m₃⋅cos (θ₂ - θ₃) + m₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) -
#
#                                                     θ₂̇
#
#                                                                       2
# ⋅m₂⋅cos(θ₁ - θ₂) + m₁⋅m₃⋅cos(θ₁ - θ₂) - m₁⋅m₃⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) + m₂ ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# ₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) - m
#
#                                                     θ₃̇
#
#                            2                  2
# m₁⋅m₃⋅cos(θ₁ - 2⋅θ₂ + θ₃) - m₂ ⋅cos(θ₁ - θ₃) + m₂ ⋅cos(θ₁ - 2⋅θ₂ + θ₃) - 2⋅m₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
# m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) -
#
#
#
#   2            2                        2    2              2⎞
# m₃ + m₂  - m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠ - (m₁ + m₂
# ──────────────────────────────────────────────────────────────────────────────
#          2                        2    2                           2    2
# m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ -
#
#
#
#                                                                     2
# cos(θ₁ - θ₂) + 2⋅m₂⋅m₃⋅cos(θ₁ - θ₂) - m₂⋅m₃⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) + m₃ ⋅co
# ──────────────────────────────────────────────────────────────────────────────
#          2                        2    2                           2    2
# ₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ -
#
#
#
#                                                2                  2
# m₃⋅cos(θ₁ - θ₃) + 2⋅m₂⋅m₃⋅cos(θ₁ - 2⋅θ₂ + θ₃) - m₃ ⋅cos(θ₁ - θ₃) + m₃ ⋅cos(θ₁
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#          2                        2    2                           2    2
# m₂⋅m₃⋅cos (θ₂ - θ₃) + 2⋅m₂⋅m₃ + m₃ ⋅cos (θ₁ - θ₂)⋅cos(θ₂ - θ₃) - m₃ ⋅cos (θ₁ -
#
#
#
#   ⎛                       2                          2
#  + m₃)⋅⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂
# ──────────────────────────────────────────────────────────────────────────────
#          2                                            2
#  θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ -
#
#
#
#          2                          ⎞                  ⎛
# s(θ₁ - θ₂) - m₃ ⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃)⎠ + (m₁ + m₂ + m₃)⋅⎝ell₁⋅m₂⋅sin(θ₁ -
# ──────────────────────────────────────────────────────────────────────────────
#          2                                            2
# θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ
#
#
#
#          ⎞
# - 2⋅θ₂ + θ₃)⎠                  ⎛                       2
# ──────────── - (m₁ + m₂ + m₃)⋅⎝ell₁⋅m₂⋅sin(θ₁ - θ₂)⋅θ₁̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂
#
# ──────────────────────────────────────────────────────────────────────────────
#          2                                            2
#  θ₂) + m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃)⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ -
#
#
#
#   2                      ⎞ ⎛  2                                    2
#  - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(θ₂)⎠⋅⎝m₂  - m₂⋅m₃⋅cos(θ₂ - θ₃) + 2⋅m₂⋅m₃ - m₃ ⋅c
# ──────────────────────────────────────────────────────────────────────────────
#         2    2              2⎞
# θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠
#
#
#
#  2                          2                          2
#  θ₂)⋅θ₁̇  + ell₁⋅m₃⋅sin(θ₁ - θ₂)⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃
# ──────────────────────────────────────────────────────────────────────────────
#         2    2              2⎞
# ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠
#
#
#
#
#     2                          2                      ⎞ ⎛
# )⋅θ₁̇  - ell₃⋅m₃⋅sin(θ₂ - θ₃)⋅θ₃̇  - g⋅(m₂ + m₃)⋅sin(θ₂)⎠⋅⎝m₁⋅m₂⋅cos(θ₂ - θ₃)
#
# ──────────────────────────────────────────────────────────────────────────────
#         2    2              2⎞
# θ₃) - m₃ ⋅cos (θ₂ - θ₃) + m₃ ⎠
#
#
#
#         2⎞
# os(θ₂ - θ₃) + m₃ ⎠⋅cos(θ₁ - θ₂)
# ───────────────────────
#
#
#
#
#
# ⎞ ⎛                  2                                                 2
# )⋅sin(θ₂)⎠⋅⎝m₁⋅m₂ + m₁⋅m₃ + m₂  - m₂⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + 2⋅m₂⋅m₃ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                        2                               2
# + m₁⋅m₃⋅cos(θ₂ - θ₃) - m₂ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + m₂ ⋅cos(θ₂ - θ₃) - 2⋅m₂
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#                          2⎞
# m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + m₃ ⎠
# ───────────────────────────
#
#
#
#
#
#
#                                                        2
# ⋅m₃⋅cos(θ₁ - θ₂)⋅cos(θ₁ - θ₃) + 2⋅m₂⋅m₃⋅cos(θ₂ - θ₃) - m₃ ⋅cos(θ₁ - θ₂)⋅cos(θ₁
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                       ⎤
#                      ⎥
#                      ⎥
#                              ⎥
#                      ⎥
#                      ⎥
#                      ⎥
#                       ⎥
#                       ⎥
#                       ⎥
#                      ⎥
#                               ⎥
#                      ⎥
#                       ⎥
#                      ⎥
#                       ⎥
#                       ⎥
#                       ⎥
#                      ⎥
#          2             ⎞⎥
#  - θ₃) + m₃ ⋅cos(θ₂ - θ₃)⎠⎥
#                      ⎥
# ─────────────────────⎥
#                      ⎥
#                      ⎦

# %%
g, m1, m2, m3, ell1, ell2, ell3, t = symbols('g m1 m2 m3 ell1 ell2 ell3 t')
theta1, theta2, theta3 = dynamicsymbols('theta1 theta2 theta3')
theta1_dot = diff(theta1, t)
theta1_ddot = diff(theta1_dot, t)

theta2_dot = diff(theta2, t)
theta2_ddot = diff(theta2_dot, t)

theta3_dot = diff(theta3, t)
theta3_ddot = diff(theta3_dot, t)


ode_theta1_ddot = lambdify((g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot), simplified_ODE1, "numpy")
ode_theta2_ddot = lambdify((g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot), simplified_ODE3, "numpy")
ode_theta3_ddot = lambdify((g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot), simplified_ODE5, "numpy")

# %%
g = 9.81
ell1 = 1
ell2 = 1
ell3 = 1
m1 = 1
m2 = 1
m3 = 1


def tripple_pendelum_ODE(t, y):

   theta1 = y[0]
   theta1_dot = y[1]
   theta2 = y[2]
   theta2_dot = y[3]
   theta3 = y[4]
   theta3_dot = y[5]

   # theta1_dd = m2*(ell1*sin(theta1 - theta2)*theta1_dot**2 - g*sin(theta2))*cos(theta1 - theta2)/(ell1*m1 + ell1*m2*cos(theta1 - theta2)**2 + ell1*m2) + (-ell2*m2*sin(theta1 - theta2)*theta2_dot**2 + g*m1*sin(theta1) + g*m2*sin(theta1))/(ell1*(m1 + m2*cos(theta1 - theta2)**2 + m2))
   theta1_dd = ode_theta1_ddot(g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot)
   
   # theta2_dd = (m1 + m2)*(ell1*sin(theta1 - theta2)*theta1_dot**2 - g*sin(theta2))/(ell2*(m1 + m2*cos(theta1 - theta2)**2 + m2)) + (-ell1*m1*cos(theta1 - theta2) - ell1*m2*cos(theta1 - theta2))*(-ell2*m2*sin(theta1 - theta2)*theta2_dot**2 + g*m1*sin(theta1) + g*m2*sin(theta1))/(ell1*(m1 + m2)*(ell2*m1 + ell2*m2*cos(theta1 - theta2)**2 + ell2*m2))
   theta2_dd = ode_theta2_ddot(g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot)

   theta3_dd = ode_theta3_ddot(g, m1, m2, m3, ell1, ell2, ell3, theta1, theta1_dot, theta2, theta2_dot, theta3, theta3_dot)


   return(theta1_dot, theta1_dd, theta2_dot, theta2_dd, theta3_dot, theta3_dd)

# %%
theta1_0 = np.deg2rad(80)
theta1_dot0 = 0
theta2_0 = np.deg2rad(80)
theta2_dot0 = 0
theta3_0 = np.deg2rad(79)
theta3_dot0 = 0


theta1_dd = 0
theta2_dd = 0
theta3_dd = 0

t = 10
frames = np.linspace(0, t, 100000*t)

#fikk chat til å skrive funksjonen basert på bildet over: 
time_points = np.linspace(0, 15, 6)  # 10 seconds, 30 frames per second
sol = solve_ivp(tripple_pendelum_ODE, [0, t], [theta1_0, theta1_dot0, theta2_0, theta2_dot0, theta3_0, theta3_dot0], t_eval=frames, method='Radau', atol=1e-13, rtol=1e-9)

theta1 = sol.y[0]
theta1_dot = sol.y[1]
theta2 = sol.y[2]
theta2_dot = sol.y[3]
theta3 = sol.y[4]
theta3_dot = sol.y[5]
t = sol.t

theta1_deg_ = np.rad2deg(sol.y[0])
theta2_deg_ = np.rad2deg(sol.y[2])
theta3_deg_ = np.rad2deg(sol.y[4])
theta1_dot_deg_ = np.rad2deg(sol.y[1])
theta2_dot_deg_ = np.rad2deg(sol.y[3])
theta3_dot_deg_ = np.rad2deg(sol.y[5])


np.savetxt('double_pend.csv', np.transpose([theta1_deg_, theta1_dot_deg_, theta2_deg_, theta2_dot_deg_, theta3_deg_, theta3_dot_deg_]), delimiter=',')
sol
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.000e-05 ...  1.000e+01  1.000e+01]
#         y: [[ 1.396e+00  1.396e+00 ...  7.885e-01  7.886e-01]
#             [ 0.000e+00 -9.661e-05 ...  2.993e+00  2.993e+00]
#             ...
#             [ 1.379e+00  1.379e+00 ...  3.603e-01  3.604e-01]
#             [ 0.000e+00  5.944e-07 ...  2.205e+00  2.205e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 52244
#      njev: 59
#       nlu: 1188

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.gridspec as gridspec

# %%
plt.plot(t, theta1_deg_, label='1')
plt.plot(t, theta3_deg_)
plt.plot(t, theta2_deg_, label='2')
plt.plot(t, theta2_dot_deg_)
plt.xlim(0,15)
plt.ylim(-360, 360)
plt.legend()

# %%
fps = 30
sec = 10
frames = sec * fps
total_frames = len(t)
frames_step = total_frames/frames
frames_step


theta1_deg = []
theta2_deg = []
theta3_deg = []
theta1_dot_deg = []
theta2_dot_deg = []
theta3_dot_deg = []


for i in range(frames):
   theta1_deg.append(theta1_deg_[int(i*frames_step)])
   theta2_deg.append(theta2_deg_[int(i*frames_step)])
   theta3_deg.append(theta3_deg_[int(i*frames_step)])
   theta1_dot_deg.append(theta1_dot_deg_[int(i*frames_step)])
   theta2_dot_deg.append(theta2_dot_deg_[int(i*frames_step)])
   theta3_dot_deg.append(theta3_dot_deg_[int(i*frames_step)])
   


# theta1_deg, theta1_dot_deg, theta2_deg, theta2_dot_deg, theta3_deg, theta3_dot_deg

# %%
def pend_pos1(theta):
   theta1 = np.deg2rad(theta)
   return (ell1*np.sin(theta1), -ell1*np.cos(theta1))

def pend_pos2(theta1_deg, theta2_deg):
   theta1 = np.deg2rad(theta1_deg)
   theta2 = np.deg2rad(theta2_deg)
   return (ell1*np.sin(theta1) + ell2*np.sin(theta2), -ell1*np.cos(theta1) - ell2*np.cos(theta2))

def pend_pos3(theta1_deg, theta2_deg, theta3_deg):
   theta1 = np.deg2rad(theta1_deg)
   theta2 = np.deg2rad(theta2_deg)
   theta3 = np.deg2rad(theta3_deg)
   return (ell1*np.sin(theta1) + ell2*np.sin(theta2) + ell3*np.sin(theta3), -ell1*np.cos(theta1) - ell2*np.cos(theta2)- ell3*np.cos(theta3))


pos1x = []
pos1y = []
pos2x = []
pos2y = []
pos3x = []
pos3y = []


for i in range(frames):
   pos1x.append(pend_pos1(theta1_deg[i])[0])
   pos1y.append(pend_pos1(theta1_deg[i])[1])
   pos2x.append(pend_pos2(theta1_deg[i], theta2_deg[i])[0])
   pos2y.append(pend_pos2(theta1_deg[i], theta2_deg[i])[1])
   pos3x.append(pend_pos3(theta1_deg[i], theta2_deg[i], theta3_deg[i])[0])
   pos3y.append(pend_pos3(theta1_deg[i], theta2_deg[i], theta3_deg[i])[1])


fig = plt.figure()
gs = gridspec.GridSpec(2,2, width_ratios=[1,2], height_ratios=[1,1])




ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[1,0])
ax2 = fig.add_subplot(gs[:,1])

theta_curve, = ax0.plot(t[0], theta1_deg[0], 'r')
theta_dot_curve, = ax0.plot(t[0], theta1_dot_deg[0], 'b')

phase_curve, = ax1.plot(theta1_deg[0], theta1_dot_deg[0], 'b')
phase_dot, = ax1.plot(theta1_deg[0], theta1_dot_deg[0], 'ro')

x0, y0 = pend_pos1(theta1_0)
x0_2, y0_2 = pend_pos2(theta1_0, theta2_0)
x0_3, y0_3 = pend_pos3(theta1_0, theta2_0, theta3_0)

line, = ax2.plot([0, x0], [0, y0], lw=2, c = 'k')
circle =ax2.add_patch(plt.Circle(pend_pos1(theta1_0), m1*0.05, fc='r', zorder=3))
line2, = ax2.plot([x0, x0_2], [y0, y0_2], lw=2, c='k')
circle2 = ax2.add_patch(plt.Circle(pend_pos2(theta1_0, theta2_0), m2*0.05, fc='g', zorder=3))
circle3 = ax2.add_patch(plt.Circle(pend_pos3(theta1_0, theta2_0, theta3_0), m3*0.05, fc='b', zorder=3))
line3, = ax2.plot([x0_2, x0_3], [y0_2, y0_3], lw=2, c='k')
dot_curve, = ax2.plot(pend_pos1(theta1_0)[0], pend_pos1(theta1_0)[1] , lw = 0.2, c = 'r', linestyle='dashed')
dot_curve2, = ax2.plot(pend_pos2(theta1_0, theta2_0)[0], pend_pos2(theta1_0, theta2_0)[1], lw=0.2, c='g', linestyle='dashed')
dot_curve3, = ax2.plot(pend_pos3(theta1_0, theta2_0, theta3_0)[0], pend_pos3(theta1_0, theta2_0, theta3_0)[1], lw=0.2, c='b', linestyle='dashed')
                      

ax0.set_xlim(0,5)
ax0.set_ylim(-400,400)

ax1.set_xlim(-100, 100)
ax1.set_ylim(-400,400)
ax1.grid()
ax0.grid()

ax2.set_xlim(-5,5)
ax2.set_ylim(-5,5)


def animate(i):
   theta_curve.set_data(t[:i+1], theta1_deg[:i+1])
   theta_dot_curve.set_data(t[:i+1], theta1_dot_deg[:i+1])

   phase_curve.set_data(theta1_deg[:i+1], theta1_dot_deg[:i+1])
   phase_dot.set_data(theta1_deg[i], theta1_dot_deg[i])

   x, y = pend_pos1(theta1_deg[i])
   x2, y2 = pend_pos2(theta1_deg[i], theta2_deg[i])
   x3, y3 = pend_pos3(theta1_deg[i], theta2_deg[i], theta3_deg[i])
   line.set_data([0, x], [0,y])
   line2.set_data([x, x2], [y, y2])
   line3.set_data([x2,x3], [y2, y3])
   circle.set_center((x,y))
   circle2.set_center((x2, y2))
   circle2.set_center((x3, y3))
   dot_curve.set_data(pos1x[:i+1], pos1y[:i+1])
   dot_curve2.set_data(pos2x[:i+1], pos2y[:i+1])
   dot_curve3.set_data(pos3x[:i+1], pos3y[:i+1])



ani = animation.FuncAnimation(fig, animate, frames=frames)
ffmpeg_writer = animation.FFMpegWriter(fps=30)
ani.save('time_domain_tripple_pend_redo_fail.mp4', writer=ffmpeg_writer)
